# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravhihz/Sentinanalytica/blob/main/Crawling_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# === Mount Google Drive dan siapkan workspace ===
from google.colab import drive
drive.mount('/content/drive')

import os, pathlib, json, datetime as _dt, atexit, signal, threading

ROOT = "/content/drive/MyDrive/MBG_Scrape"   # lokasi utama
pathlib.Path(ROOT).mkdir(parents=True, exist_ok=True)
os.chdir(ROOT)
print("Working dir:", os.getcwd())

# === Masukkan token X ===
import os
os.environ["TWITTER_AUTH_TOKEN"] = "fc0c7f0994e119584e73dd08d0e652cd9f5e10ff"
assert os.getenv("TWITTER_AUTH_TOKEN"), "Set dulu os.environ['TWITTER_AUTH_TOKEN']"


# === Util umum untuk state (tahan crash) ===
def atomic_write_json(path, data):
    tmp = path + ".tmp"
    with open(tmp, "w") as f:
        json.dump(data, f, indent=2)
        f.flush(); os.fsync(f.fileno())
    os.replace(tmp, path)

def make_state(STATEF):
    state = {"done_files": [], "total_rows": 0, "last_run": None}
    def load():
        nonlocal state
        if os.path.exists(STATEF):
            with open(STATEF) as f: state = json.load(f)
            print(f"▶️ resume: {STATEF} | windows={len(state['done_files'])} | rows={state['total_rows']}")
        else:
            print(f"▶️ start fresh (no {STATEF})")
        return state
    def save():
        state["last_run"] = _dt.datetime.now(_dt.UTC).isoformat()
        atomic_write_json(STATEF, state)
        print(f"💾 checkpoint → {STATEF} | windows={len(state['done_files'])} | rows={state['total_rows']}")
    return state, load, save

def start_checkpoint_timer(save_fn, interval=300):
    def tick():
        try: save_fn()
        finally:
            t = threading.Timer(interval, tick); t.daemon = True; t.start()
    t = threading.Timer(interval, tick); t.daemon = True; t.start()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Working dir: /content/drive/MyDrive/MBG_Scrape

# %%
import os, datetime as dt, subprocess, shlex, pandas as pd, glob, random, time, shutil, re, pathlib
from pandas.errors import EmptyDataError, ParserError

# ====== STATE ======
STATEF = "state_text.json"
state, load_state, save_state = make_state(STATEF)
state = load_state()
start_checkpoint_timer(save_state, 300)

def _on_exit(*_):
    try: print("⚠️ runtime exiting (TEXT)…"); save_state()
    except: pass
atexit.register(_on_exit); signal.signal(signal.SIGTERM,_on_exit); signal.signal(signal.SIGINT,_on_exit)

# ====== PARAM ======
START = dt.date(2025, 1, 6)
END   = dt.date(2025, 10, 6)              # bisa juga: dt.date.today()
TODAY = dt.date.today()
SAFE_END = min(END, TODAY)                # jangan melewati hari ini

WINDOW_DAYS       = 3
PER_WINDOW_LIMIT  = 160
TAB               = "TOP"
OUTDIR            = "text_chunks"
MERGED            = "mbg_text_merged.csv"
ARCH_EMPTY        = "empty_windows"
pathlib.Path(OUTDIR).mkdir(exist_ok=True)
pathlib.Path(ARCH_EMPTY).mkdir(exist_ok=True)

BASE_QUERY = r'("makan bergizi gratis" OR "program makan bergizi" OR MBG OR "keracunan mbg") lang:id -is:retweet'

POSSIBLE_DIRS = [
    "/content/tweets-data",
    os.path.join(os.getcwd(), "tweets-data"),
    "/content/drive/MyDrive/MBG_Scrape/tweets-data",
]

# ====== HELPERS ======
def windows(start, end, step):
    d = start
    hard_until = min(end + dt.timedelta(days=1), TODAY + dt.timedelta(days=1))
    while d < hard_until:
        e = min(d + dt.timedelta(days=step), hard_until)
        yield d, e
        d = e

def _find_csv_after_run(base, retries=3, sleep_s=5):
    # cari file hasil tweet-harvest di banyak lokasi + retry (sinkronisasi Drive)
    patterns = []
    for d in POSSIBLE_DIRS:
        patterns += glob.glob(os.path.join(d, f"{base}.csv"))
        patterns += glob.glob(os.path.join(d, f"{base}*.csv"))
    patterns += glob.glob(f"{base}.csv")
    if patterns:
        patterns.sort(key=os.path.getmtime, reverse=True)
        return patterns[0]
    if retries <= 0:
        return None
    time.sleep(sleep_s)
    return _find_csv_after_run(base, retries-1, sleep_s)

def is_empty_csv(path: str) -> bool:
    try:
        if (not os.path.exists(path)) or os.path.getsize(path) < 32:
            return True
        pd.read_csv(path, nrows=1)   # peek
        return False
    except (EmptyDataError, ParserError, UnicodeDecodeError):
        return True
    except Exception:
        return True

def run_window(s, e, idx, base):
    out = f"{OUTDIR}/{base}.csv"
    if os.path.exists(out) or base in state.get("done_files", []):
        print(f"[T{idx:03d}] SKIP {out}")
        return out

    q = f'{BASE_QUERY} since:{s:%Y-%m-%d} until:{e:%Y-%m-%d}'
    cmd = f'npx -y tweet-harvest@2.6.1 -o "{base}" -s {shlex.quote(q)} --tab "{TAB}" -l {PER_WINDOW_LIMIT} --token "{os.environ["TWITTER_AUTH_TOKEN"]}"'
    print(f"\n[T{idx:03d}] {s}→{e}\n{q}")

    p = subprocess.run(cmd, shell=True, capture_output=True, text=True)

    if p.returncode == 0:
        # coba tangkap "saved to: ..." dari stdout/stderr
        m = re.search(r'saved to:\s+"?(.+?\.csv)"?', (p.stdout or "") + (p.stderr or ""), re.I)
        src = m.group(1) if m and os.path.exists(m.group(1)) else _find_csv_after_run(base)
        if src and os.path.exists(src):
            shutil.move(src, out)
            # validasi konten
            if is_empty_csv(out):
                print("  [WARN] kosong →", out, " (arsipkan)")
                shutil.move(out, os.path.join(ARCH_EMPTY, os.path.basename(out)))
                return None
            print("  [OK] ", out)
            return out

    print("  [WARN] CSV belum ketemu. Cek kemungkinan lokasi:"); [print("   -", d) for d in POSSIBLE_DIRS]
    return None

# ====== MAIN LOOP ======
files = sorted(glob.glob(f"{OUTDIR}/text_*.csv"))
for i, (s, e) in enumerate(windows(START, SAFE_END, WINDOW_DAYS), 1):
    base = f"text_{s:%Y%m%d}_{(e - dt.timedelta(days=1)):%Y%m%d}"
    out = run_window(s, e, i, base)
    time.sleep(random.randint(8, 15))
    if out and os.path.exists(out):
        try:
            if is_empty_csv(out):
                print("  [SKIP] CSV kosong:", out)
                shutil.move(out, os.path.join(ARCH_EMPTY, os.path.basename(out)))
                continue
            df = pd.read_csv(out)
            rows = len(df)
            # update state
            if base not in state["done_files"]:
                state["done_files"].append(base)
            state["total_rows"] = int(state.get("total_rows", 0) + rows)
            save_state()
            files.append(out)
            print(f"  [+] {rows} rows | total={state['total_rows']}")
        except EmptyDataError:
            print(f"  [WARN] EmptyDataError reading file: {out}")
            shutil.move(out, os.path.join(ARCH_EMPTY, os.path.basename(out)))
        except Exception as e:
            print(f"  [ERROR] {out}: {type(e).__name__} → {e}")

# ====== MERGE AMAN ======
parts = sorted([p for p in glob.glob(f"{OUTDIR}/text_*.csv") if not is_empty_csv(p)])
if parts:
    dfs = []
    for pth in parts:
        try:
            df = pd.read_csv(pth)
            if not df.empty:
                dfs.append(df)
        except Exception as e:
            print("[SKIP]", os.path.basename(pth), "→", type(e).__name__)
    if dfs:
        big = pd.concat(dfs, ignore_index=True)
        id_col = next((c for c in ["id_str","tweet_id","id","status_id"] if c in big.columns), None)
        if id_col:
            big = big.drop_duplicates(subset=[id_col])
        else:
            txt = "full_text" if "full_text" in big.columns else ("text" if "text" in big.columns else None)
            if txt: big = big.drop_duplicates(subset=[txt])
        big.to_csv(MERGED, index=False, encoding="utf-8")
        print(f"✅ MERGED → {MERGED} | rows={len(big)}")
    else:
        print("⚠️ Tidak ada DataFrame valid untuk merge.")
else:
    print("⚠️ Tidak ada CSV valid untuk digabung.")
# Out:
# ▶️ resume: state_text.json | windows=96 | rows=44879
# [T001] SKIP text_chunks/text_20250106_20250108.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45018
#   [+] 139 rows | total=45018
# [T002] SKIP text_chunks/text_20250109_20250111.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45157
#   [+] 139 rows | total=45157
# [T003] SKIP text_chunks/text_20250112_20250114.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45310
#   [+] 153 rows | total=45310
# [T004] SKIP text_chunks/text_20250115_20250117.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=44879
# 💾 checkpoint → state_text.json | windows=96 | rows=45389
#   [+] 79 rows | total=45389
# [T005] SKIP text_chunks/text_20250118_20250120.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45531
#   [+] 142 rows | total=45531
# [T006] SKIP text_chunks/text_20250121_20250123.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45681
#   [+] 150 rows | total=45681
# [T007] SKIP text_chunks/text_20250124_20250126.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45805
#   [+] 124 rows | total=45805
# [T008] SKIP text_chunks/text_20250127_20250129.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45824
#   [+] 19 rows | total=45824
# [T009] SKIP text_chunks/text_20250130_20250201.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=45939
#   [+] 115 rows | total=45939
# [T010] SKIP text_chunks/text_20250202_20250204.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46093
#   [+] 154 rows | total=46093
# [T011] SKIP text_chunks/text_20250205_20250207.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46249
#   [+] 156 rows | total=46249
# [T012] SKIP text_chunks/text_20250208_20250210.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46374
#   [+] 125 rows | total=46374
# [T013] SKIP text_chunks/text_20250211_20250213.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46534
#   [+] 160 rows | total=46534
# [T014] SKIP text_chunks/text_20250214_20250216.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46658
#   [+] 124 rows | total=46658
# [T015] SKIP text_chunks/text_20250217_20250219.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46810
#   [+] 152 rows | total=46810
# [T016] SKIP text_chunks/text_20250220_20250222.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46960
#   [+] 150 rows | total=46960
# [T017] SKIP text_chunks/text_20250223_20250225.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=46979
#   [+] 19 rows | total=46979
# [T018] SKIP text_chunks/text_20250226_20250228.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47078
#   [+] 99 rows | total=47078
# [T019] SKIP text_chunks/text_20250301_20250303.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47197
#   [+] 119 rows | total=47197
# [T020] SKIP text_chunks/text_20250304_20250306.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47317
#   [+] 120 rows | total=47317
# [T021] SKIP text_chunks/text_20250307_20250309.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47436
#   [+] 119 rows | total=47436
# [T022] SKIP text_chunks/text_20250310_20250312.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47570
#   [+] 134 rows | total=47570
# [T023] SKIP text_chunks/text_20250313_20250315.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47710
#   [+] 140 rows | total=47710
# [T024] SKIP text_chunks/text_20250316_20250318.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47828
#   [+] 118 rows | total=47828
# [T025] SKIP text_chunks/text_20250319_20250321.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=47927
#   [+] 99 rows | total=47927
# [T026] SKIP text_chunks/text_20250322_20250324.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48066
#   [+] 139 rows | total=48066
# [T027] SKIP text_chunks/text_20250325_20250327.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48066
# 💾 checkpoint → state_text.json | windows=96 | rows=48152
#   [+] 86 rows | total=48152
# [T028] SKIP text_chunks/text_20250328_20250330.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48294
#   [+] 142 rows | total=48294
# [T029] SKIP text_chunks/text_20250331_20250402.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48430
#   [+] 136 rows | total=48430
# [T030] SKIP text_chunks/text_20250403_20250405.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=44879
# 💾 checkpoint → state_text.json | windows=96 | rows=48589
#   [+] 159 rows | total=48589
# [T031] SKIP text_chunks/text_20250406_20250408.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48708
#   [+] 119 rows | total=48708
# [T032] SKIP text_chunks/text_20250409_20250411.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48727
#   [+] 19 rows | total=48727
# [T033] SKIP text_chunks/text_20250412_20250414.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48828
#   [+] 101 rows | total=48828
# [T034] SKIP text_chunks/text_20250415_20250417.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=48956
#   [+] 128 rows | total=48956
# [T035] SKIP text_chunks/text_20250418_20250420.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49096
#   [+] 140 rows | total=49096
# [T036] SKIP text_chunks/text_20250421_20250423.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49231
#   [+] 135 rows | total=49231
# [T037] SKIP text_chunks/text_20250424_20250426.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49354
#   [+] 123 rows | total=49354
# [T038] SKIP text_chunks/text_20250427_20250429.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49479
#   [+] 125 rows | total=49479
# [T039] SKIP text_chunks/text_20250430_20250502.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49612
#   [+] 133 rows | total=49612
# [T040] SKIP text_chunks/text_20250503_20250505.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49780
#   [+] 168 rows | total=49780
# [T041] SKIP text_chunks/text_20250506_20250508.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49919
#   [+] 139 rows | total=49919
# [T042] SKIP text_chunks/text_20250509_20250511.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=49998
#   [+] 79 rows | total=49998
# [T043] SKIP text_chunks/text_20250512_20250514.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50089
#   [+] 91 rows | total=50089
# [T044] SKIP text_chunks/text_20250515_20250517.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50209
#   [+] 120 rows | total=50209
# [T045] SKIP text_chunks/text_20250518_20250520.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50365
#   [+] 156 rows | total=50365
# [T046] SKIP text_chunks/text_20250521_20250523.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50487
#   [+] 122 rows | total=50487
# [T047] SKIP text_chunks/text_20250524_20250526.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50619
#   [+] 132 rows | total=50619
# [T048] SKIP text_chunks/text_20250527_20250529.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50716
#   [+] 97 rows | total=50716
# [T049] SKIP text_chunks/text_20250530_20250601.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50862
#   [+] 146 rows | total=50862
# [T050] SKIP text_chunks/text_20250602_20250604.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=50979
#   [+] 117 rows | total=50979
# [T051] SKIP text_chunks/text_20250605_20250607.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51044
#   [+] 65 rows | total=51044
# [T052] SKIP text_chunks/text_20250608_20250610.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51083
#   [+] 39 rows | total=51083
# [T053] SKIP text_chunks/text_20250611_20250613.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51083
# 💾 checkpoint → state_text.json | windows=96 | rows=51177
#   [+] 94 rows | total=51177
# [T054] SKIP text_chunks/text_20250614_20250616.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51309
#   [+] 132 rows | total=51309
# [T055] SKIP text_chunks/text_20250617_20250619.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51428
#   [+] 119 rows | total=51428
# [T056] SKIP text_chunks/text_20250620_20250622.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51559
#   [+] 131 rows | total=51559
# [T057] SKIP text_chunks/text_20250623_20250625.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=44879
# 💾 checkpoint → state_text.json | windows=96 | rows=51598
#   [+] 39 rows | total=51598
# [T058] SKIP text_chunks/text_20250626_20250628.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51717
#   [+] 119 rows | total=51717
# [T059] SKIP text_chunks/text_20250629_20250701.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51856
#   [+] 139 rows | total=51856
# [T060] SKIP text_chunks/text_20250702_20250704.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=51984
#   [+] 128 rows | total=51984
# [T061] SKIP text_chunks/text_20250705_20250707.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52081
#   [+] 97 rows | total=52081
# [T062] SKIP text_chunks/text_20250708_20250710.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52222
#   [+] 141 rows | total=52222
# [T063] SKIP text_chunks/text_20250711_20250713.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52323
#   [+] 101 rows | total=52323
# [T064] SKIP text_chunks/text_20250714_20250716.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52420
#   [+] 97 rows | total=52420
# [T065] SKIP text_chunks/text_20250717_20250719.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52561
#   [+] 141 rows | total=52561
# [T066] SKIP text_chunks/text_20250720_20250722.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52695
#   [+] 134 rows | total=52695
# [T067] SKIP text_chunks/text_20250723_20250725.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52817
#   [+] 122 rows | total=52817
# [T068] SKIP text_chunks/text_20250726_20250728.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=52910
#   [+] 93 rows | total=52910
# [T069] SKIP text_chunks/text_20250729_20250731.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53009
#   [+] 99 rows | total=53009
# [T070] SKIP text_chunks/text_20250801_20250803.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53158
#   [+] 149 rows | total=53158
# [T071] SKIP text_chunks/text_20250804_20250806.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53257
#   [+] 99 rows | total=53257
# [T072] SKIP text_chunks/text_20250807_20250809.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53381
#   [+] 124 rows | total=53381
# [T073] SKIP text_chunks/text_20250810_20250812.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53500
#   [+] 119 rows | total=53500
# [T074] SKIP text_chunks/text_20250813_20250815.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53608
#   [+] 108 rows | total=53608
# [T075] SKIP text_chunks/text_20250816_20250818.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53729
#   [+] 121 rows | total=53729
# [T076] SKIP text_chunks/text_20250819_20250821.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53748
#   [+] 19 rows | total=53748
# [T077] SKIP text_chunks/text_20250822_20250824.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=53887
#   [+] 139 rows | total=53887
# [T078] SKIP text_chunks/text_20250825_20250827.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54011
#   [+] 124 rows | total=54011
# [T079] SKIP text_chunks/text_20250828_20250830.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54011
# 💾 checkpoint → state_text.json | windows=96 | rows=54129
#   [+] 118 rows | total=54129
# [T080] SKIP text_chunks/text_20250831_20250902.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54291
#   [+] 162 rows | total=54291
# [T081] SKIP text_chunks/text_20250903_20250905.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54350
#   [+] 59 rows | total=54350
# [T082] SKIP text_chunks/text_20250906_20250908.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=44879
# 💾 checkpoint → state_text.json | windows=96 | rows=54433
#   [+] 83 rows | total=54433
# [T083] SKIP text_chunks/text_20250909_20250911.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54545
#   [+] 112 rows | total=54545
# [T084] SKIP text_chunks/text_20250912_20250914.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54670
#   [+] 125 rows | total=54670
# [T085] SKIP text_chunks/text_20250915_20250917.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54819
#   [+] 149 rows | total=54819
# [T086] SKIP text_chunks/text_20250918_20250920.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54838
#   [+] 19 rows | total=54838
# [T087] SKIP text_chunks/text_20250921_20250923.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=54937
#   [+] 99 rows | total=54937
# [T088] SKIP text_chunks/text_20250924_20250926.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=55076
#   [+] 139 rows | total=55076
# [T089] SKIP text_chunks/text_20250927_20250929.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=55210
#   [+] 134 rows | total=55210
# [T090] SKIP text_chunks/text_20250930_20251002.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=55364
#   [+] 154 rows | total=55364
# [T091] SKIP text_chunks/text_20251003_20251005.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=55496
#   [+] 132 rows | total=55496
# [T092] SKIP text_chunks/text_20251006_20251006.csv
# 💾 checkpoint → state_text.json | windows=96 | rows=55615
#   [+] 119 rows | total=55615
# ✅ MERGED → mbg_text_merged.csv | rows=11257
